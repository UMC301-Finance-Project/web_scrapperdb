# %%
# !export FINNHUB_API_KEY='cshqdo9r01qg5burvvogcshqdo9r01qg5burvvp0' # Get an API hey from https://finnhub.io/

# %%
import os
os.environ['FINNHUB_API_KEY'] = 'cshqdo9r01qg5burvvogcshqdo9r01qg5burvvp0'

# %%
import os
import finnhub
import pandas as pd
import re
from datetime import datetime, timedelta

class StockNewsExtractor:
    def __init__(self, api_key=None, output_dir='stock_news'):
        """
        Initialize the Stock News Extractor
        
        Args:
            api_key (str, optional): Finnhub API key. If not provided, 
                                     will look for environment variable.
            output_dir (str, optional): Directory to save news files
        """
        # Prioritize passed API key, then environment variable
        if api_key:
            self.api_key = api_key
        else:
            self.api_key = os.environ.get('FINNHUB_API_KEY')
        
        if not self.api_key:
            raise ValueError("No Finnhub API key found. Set FINNHUB_API_KEY environment variable or pass key directly.")
        
        self.output_dir = output_dir
        
        # Ensure output directories exist
        os.makedirs(output_dir, exist_ok=True)
        os.makedirs(os.path.join(output_dir, 'summaries'), exist_ok=True)

    def _is_valid_news_article(self, article):
        """
        Validate if the article is a legitimate news piece
        
        Args:
            article (dict): News article dictionary
        
        Returns:
            bool: True if article appears to be valid, False otherwise
        """
        # Comprehensive ad and spam detection
        ad_keywords = [
            'advertisement', 'sponsored', 'promoted', 'advertisement content', 
            'paid content', 'sponsored content', 'this is an advertisement', 
            'ad by', 'ads by', 'sponsored by', 'promoted by',
            'zacks.com', 'financial research', 'stock market analysis'
        ]
        
        # Check for minimum required fields
        if not all(key in article for key in ['headline', 'summary', 'url']):
            return False
        
        # Convert text to lowercase for case-insensitive checking
        headline_lower = article['headline'].lower()
        summary_lower = article.get('summary', '').lower()
        
        # Advanced ad detection
        if any(keyword in headline_lower or keyword in summary_lower for keyword in ad_keywords):
            return False
        
        # Check for minimum length of summary
        if len(str(article.get('summary', '')).strip()) < 20:
            return False
        
        # Reject articles with obvious spam patterns
        spam_patterns = [
            r'\b(buy|sell)\s+now\b',
            r'limited\s+time\s+offer',
            r'exclusive\s+deal',
            r'\$\d+\s*profit'
        ]
        
        if any(re.search(pattern, headline_lower) or re.search(pattern, summary_lower) 
               for pattern in spam_patterns):
            return False
        
        return True

    def extract_and_save_news_summaries(self, ticker_symbol, days_back=30):
        """
        Extract news, save to CSV, and save summaries to a text file
        
        Args:
            ticker_symbol (str): Stock ticker symbol
            days_back (int, optional): Number of days to look back
        
        Returns:
            list: List of valid news summaries with dates
        """
        try:
            # Initialize Finnhub client
            finnhub_client = finnhub.Client(api_key=self.api_key)
            
            # Define time frame
            today = datetime.utcnow()
            past_date = today - timedelta(days=days_back)
            
            # Fetch company news
            news = finnhub_client.company_news(
                ticker_symbol, 
                _from=past_date.strftime('%Y-%m-%d'), 
                to=today.strftime('%Y-%m-%d')
            )
            
            if not news:
                print(f"No news found for ticker {ticker_symbol}")
                return []
            
            # Filter out invalid articles
            valid_news = [article for article in news if self._is_valid_news_article(article)]
            
            if not valid_news:
                print(f"No valid news articles found for ticker {ticker_symbol}")
                return []
            
            # Convert to DataFrame
            news_df = pd.DataFrame(valid_news)
            news_df['ticker'] = ticker_symbol
            # Convert timestamp to readable datetime
            news_df['readable_datetime'] = pd.to_datetime(news_df['datetime'], unit='s').dt.strftime('%Y-%m-%d %H:%M:%S')
            news_df.columns = list(news_df.columns)
            # Create timestamp for filenames
            timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
            
            # Save news to CSV
            csv_filename = f"{ticker_symbol}_news_{timestamp}.csv"
            csv_filepath = os.path.join(self.output_dir, csv_filename)
            news_df.to_csv(csv_filepath, index=False, encoding='utf-8')
            print(f"News saved to {csv_filepath}")
            
            # Prepare summaries with dates
            detailed_summaries = [
                f"[{row['readable_datetime']}] {row['headline']}: {row['summary']}"
                for _, row in news_df.iterrows()
            ]
            
            # Save summaries to text file
            summary_filename = f"{ticker_symbol}_summaries_{timestamp}.txt"
            summary_filepath = os.path.join(self.output_dir, 'summaries', summary_filename)
            with open(summary_filepath, 'w', encoding='utf-8') as f:
                f.write(f"News Summaries for {ticker_symbol} on {timestamp}\n")
                f.write("=" * 50 + "\n\n")
                for idx, summary in enumerate(detailed_summaries, 1):
                    f.write(f"{idx}. {summary}\n\n")
            
            print(f"Summaries saved to {summary_filepath}")
            print(f"Total valid news articles: {len(detailed_summaries)}")
            
            return detailed_summaries
        
        except Exception as e:
            print(f"Error extracting news: {e}")
            return []

def get_nifty_50_tickers():
    """
    Returns a list of NIFTY 50 stock tickers (as of 2024)
    
    Returns:
        list: NIFTY 50 stock tickers
    """
    return [
        'AAPL', 'MSFT', 'AMZN', 'GOOGL', 'GOOG', 'TSLA', 'NVDA', 'JPM'
    ]

def main():
    try:
        # Create extractor without hardcoding the API key
        extractor = StockNewsExtractor()
        
        # Get all NIFTY 50 tickers
        nifty_tickers = get_nifty_50_tickers()
        
        # Collector for all news
        all_news = []
        
        # Extract news for each ticker
        for ticker in nifty_tickers:
            #print(f"\nFetching news for {ticker}")
            ticker_news = extractor.extract_and_save_news_summaries(ticker, days_back=7)
            all_news.extend(ticker_news)
        
        # Display all news
        #print("\n--- Consolidated NIFTY 50 News ---")
        #for idx, news in enumerate(all_news, 1):
            #print(f"{idx}. {news}")
    
    except ValueError as ve:
        print(f"Configuration Error: {ve}")
    except Exception as e:
        print(f"Unexpected error: {e}")

main()
# Out:
# /tmp/ipykernel_14717/1516068698.py:96: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   today = datetime.utcnow()
# News saved to stock_news/AAPL_news_20241103_074144.csv
# Summaries saved to stock_news/summaries/AAPL_summaries_20241103_074144.txt
# Total valid news articles: 132
# /tmp/ipykernel_14717/1516068698.py:96: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   today = datetime.utcnow()
# News saved to stock_news/MSFT_news_20241103_074145.csv
# Summaries saved to stock_news/summaries/MSFT_summaries_20241103_074145.txt
# Total valid news articles: 106
# /tmp/ipykernel_14717/1516068698.py:96: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   today = datetime.utcnow()
# News saved to stock_news/AMZN_news_20241103_074147.csv
# Summaries saved to stock_news/summaries/AMZN_summaries_20241103_074147.txt
# Total valid news articles: 134
# /tmp/ipykernel_14717/1516068698.py:96: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   today = datetime.utcnow()
# News saved to stock_news/GOOGL_news_20241103_074148.csv
# Summaries saved to stock_news/summaries/GOOGL_summaries_20241103_074148.txt
# Total valid news articles: 145
# /tmp/ipykernel_14717/1516068698.py:96: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   today = datetime.utcnow()
# News saved to stock_news/GOOG_news_20241103_074149.csv
# Summaries saved to stock_news/summaries/GOOG_summaries_20241103_074149.txt
# Total valid news articles: 153
# /tmp/ipykernel_14717/1516068698.py:96: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   today = datetime.utcnow()
# News saved to stock_news/TSLA_news_20241103_074151.csv
# Summaries saved to stock_news/summaries/TSLA_summaries_20241103_074151.txt
# Total valid news articles: 115
# /tmp/ipykernel_14717/1516068698.py:96: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   today = datetime.utcnow()
# News saved to stock_news/NVDA_news_20241103_074152.csv
# Summaries saved to stock_news/summaries/NVDA_summaries_20241103_074152.txt
# Total valid news articles: 112
# /tmp/ipykernel_14717/1516068698.py:96: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   today = datetime.utcnow()
# News saved to stock_news/JPM_news_20241103_074153.csv
# Summaries saved to stock_news/summaries/JPM_summaries_20241103_074153.txt
# Total valid news articles: 44

# %%
import pandas as pd
import glob

# Path to the summaries directory
path = 'stock_news/'

# Use glob to find all CSV files in the directory
csv_files = glob.glob(path + "*.csv")

# Create a dictionary to store each CSV with the stock ticker as the key
dataframes = {}

# Loop through each file and read it into a DataFrame
for file in csv_files:
    # Extract the stock ticker from the filename (e.g., AAPL, AMZN)
    stock_ticker = file.split('/')[-1].split('_')[0]
    
    # Read the CSV file and store it in the dictionary
    dataframes[stock_ticker] = pd.read_csv(file)

# %%
import pandas as pd

# %%
df = pd.concat(dataframes.values(), ignore_index=True)

# %%
dfg = df.groupby('ticker')

# %%
import sqlite3

# Database file path
db_file_path = 'stock_news.db'

# Connect to the SQLite database (it will be created if it doesn't exist)
connection = sqlite3.connect(db_file_path)
cursor = connection.cursor()

# Create a table for news articles
cursor.execute('''
CREATE TABLE IF NOT EXISTS news_articles (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    stock_symbol TEXT,
    headline TEXT,
    published_date TEXT,
    sentiment REAL
)
''')

# %%
for ticker, group in dfg:
    # Insert each row as a record into the database
    for idx, row in group.iterrows():
        cursor.execute('''
        INSERT INTO news_articles (stock_symbol, headline, published_date)
        VALUES (?, ?, ?)
        ''', (row['ticker'], row['headline'], row['readable_datetime']))
        print(f"Inserted {row['headline']}")
# Out:
# Inserted CVS Health, Apollo Global Management, And Novo Nordisk Reported Results
# Inserted Warren Buffett is sitting on over $325 billion cash as Berkshire Hathaway keeps selling Apple stock
# Inserted Decoding Apple Inc (AAPL): A Strategic SWOT Insight
# Inserted The Noisiest 10 Days Of The Year
# Inserted Apple acquires photo editor Pixelmator
# Inserted Breaking Down Magnificent 7 Earnings Results
# Inserted Mag 7 earnings, election volatility, bitcoin: Market Takeaways
# Inserted AI Spending Dominated Big Tech Earnings. Why These 2 Stocks Got a Pass From Investors.
# Inserted Globalstar Soars 64% on Expanded Apple Partnership, Forecasts Revenue Doubling
# Inserted Apple needs AI hype to drive upgrades but can't disappoint users
# Inserted Stock Market Today: Indexes Fade Into The Close; Amazon Holds Above Buy Point (Live Coverage)
# Inserted Apple, Amazon, Intel, Boeing, Super Micro, Exxon, and More Stock Market Movers
# Inserted Sector Update: Tech Stocks Gain Late Afternoon
# Inserted Globalstar stock surges on potential $1.5B Apple investment: Reuters
# Inserted Apple’s Earnings Confirmed 1 Thing: Nobody Knows When a Major Upgrade Cycle Is Coming
# Inserted What We Learned About AI From This Week's Big Tech Earnings
# Inserted Midday stock movers: Amazon, Apple, Intel and more
# Inserted Apple's Tepid Forecast, China Weakness Spark Concern
# Inserted Netflix has ‘won’ the streaming wars — here’s how others will compete
# Inserted Apple Stock Dips on Mixed Outlook, Analysts Eye AI as Key for Growth
# Inserted Communications Up in Anticipation of Deal Activity -- Communications Services Roundup
# Inserted ChatGPT: Everything you need to know about the AI-powered chatbot
# Inserted Stock Market Today: Dow Jones Adds 400 Points; Trump Stock Dives As Super Micro Erases Year's Gains (Live Coverage)
# Inserted Apple Posts Hefty Cash Flow and Record Shareholder Returns, Yet Stock Dips
# Inserted Apple is buying photo-editing app Pixelmator
# Inserted Apple's delayed AI launch a 'real risk' to upgrade cycle: Analyst
# Inserted Heard on the Street: Apple’s Forecast Shows AI Cycle Playing Out Slowly
# Inserted If You'd Invested $1,000 in Apple Stock 10 Years Ago, Here's How Much You'd Have Today
# Inserted Tim Cook says he uses ‘a very good formula’ to look for Apple employees—these are the 4 traits he seeks out
# Inserted Stock Market Retreats Before Election Day; Microsoft, Apple, Amazon, Google, Meta In Focus: Weekly Review
# Inserted Apple Stock Sinks On Disappointing Sales Outlook
# Inserted Apple to invest up to $1.5 billion in Globalstar for satellite coverage expansion
# Inserted Top Stock Movers Now: Amazon, Charter Communications, Apple, and More
# Inserted Top Midday Stories: Amazon Shares Rise on Earnings Beat; Union Endorses Boeing's Latest Contract Proposal
# Inserted Apple's iPhone Sales grew 6% with AI Enhancements, Surpassing Expectations
# Inserted Apple Tops Q4 Earnings & Revenue Estimates: Buy, Sell or Hold Shares?
# Inserted Apple Inc. (AAPL) Unveils New MacBook Pro with M4 Chips, Enhancing Performance and AI Integration for Users
# Inserted Apple Reports Record Q4 iPhone Sales but Stock Dips: ETFs in Focus
# Inserted Apple stock under pressure after earnings: What you need to know
# Inserted 5 Wall Street analysts discuss Apple stock outlook after a mixed earnings report
# Inserted Apple reports better-than-anticipated Q4 revenue, earnings hurt by EU tax payment
# Inserted Globalstar Expands Satellite Services Deal With Apple
# Inserted October jobs report, Amazon and Apple, Boeing deal: 3 Things
# Inserted Globalstar stock rockets 40% on expanded satellite service deal with Apple
# Inserted Trending tickers: Apple, Amazon, Nvidia, Intel and Microsoft
# Inserted Q4 2024 Apple Inc Earnings Call
# Inserted Analysts revisit Apple stock price targets after earnings, iPhone 16 outlook
# Inserted These Stocks Are Moving the Most Today: Apple, Amazon, Intel, Atlassian, Exxon, Chevron, and More
# Inserted US added far fewer jobs than expected in October, Amazon & Intel lead tech stocks: Yahoo Finance
# Inserted The Rotation Out Of Technology Should Come As No Surprise
# Inserted The Stocks Selloff Was a Halloween Fright. Why Markets Could Face More Shocks and 5 Other Things to Know Today.
# Inserted Apple Fiscal Fourth-Quarter Results Top Views Despite $10.2 Billion Tax Charge
# Inserted Apple Sparks Concerns With Tepid Forecast, China Weakness
# Inserted Column: These Apple researchers just showed that AI bots can't think, and possibly never will
# Inserted Apple's China sales continue to fall after Cook's charm offensive in Beijing
# Inserted FTSE 100 LIVE: Stocks tick up as Reeves seeks to calm bond markets
# Inserted Apple Stock Slips in Premarket as Investors Fret About Weak Sales Guidance
# Inserted Meet the Unstoppable Stock That Could Join Apple, Nvidia, and Microsoft in the $3 Trillion Club Next Year
# Inserted Meet the Supercharged Growth Stock That Could Join Apple, Nvidia, Microsoft, and Alphabet in the $2 Trillion Club by 2028
# Inserted Apple Inc (AAPL) Q4 2024 Earnings Call Highlights: Record Revenue and Strong Services Growth
# Inserted Indonesia bans sales of Google phones days after blocking Apple's iPhone 16
# Inserted Apple : Annual Report for Fiscal Year Ending September 28, 2024 (Form 10-K)
# Inserted After iPhone 16s, Indonesia Blocks Google Pixel Phones: Kontan
# Inserted Apple: EPS up 12% in Q4
# Inserted Apple, Amazon shares steady in Frankfurt after results
# Inserted Indonesia bans sales of Google smartphones days after blocking Apple's iPhone 16
# Inserted Apple Sales Hit Quarterly Record as iPhone Business Rebounds
# Inserted Apple Q4: Apple Intelligence And Services To Drive Future Growth, Upgrade To 'Buy'
# Inserted Apple: The World's Most Boring Way To Make Money
# Inserted Apple : FY 24 Fourth Quarter Results (Listen to the conference call webcast)
# Inserted Nasdaq, S&P 500 sell off ahead of Amazon, Apple earnings
# Inserted Intel stock jumps on positive outlook, despite Q3 losses
# Inserted Peloton Soars To A New High Amid This Move To Get Fit
# Inserted Apple Inc. (AAPL): Among The 10 Best S&P 500 Stocks to Buy According to Hedge Funds
# Inserted Apple Inc. (AAPL) Q4 2024 Earnings Call Transcript
# Inserted Amazon Q3: Double Beat Makes Shares Jump
# Inserted Apple Earnings: Q4 Results Decent, But Questions Continue Into Q1 2025
# Inserted What Wall Street Analysts Think of Apple's Stock Ahead of Earnings Thursday
# Inserted Apple : reports fourth quarter results Form 8 K
# Inserted How To Earn $500 A Month From Apple Stock Ahead Of Quarterly Earnings
# Inserted Apple Earnings: What to Watch Out For
# Inserted What Wall Street Is Saying Ahead of Earnings
# Inserted Heard on the Street: Why Apple’s AI Fortunes Rely on Latest iPhones
# Inserted Apple sells $46 billion worth of iPhones over the summer as AI helps end slump
# Inserted Meta, Microsoft stocks tumble as Big Tech's AI splurge prompts investor caution
# Inserted Apple's iPhone sales bounce back from recent slump amid AI expansion, but stock still dips
# Inserted The Dow falls 250 points and the Nasdaq sinks 340 as Microsoft and Meta lead a tech stock selloff
# Inserted Apple: Fiscal Q4 Earnings Snapshot
# Inserted Apple reports fourth quarter results
# Inserted Apple beats Wall Street estimates, supported by iPhone sales
# Inserted Apple Inc. (AAPL) Launches New Mac Mini with M4 and M4 Pro Chips, Promising Unmatched Performance in a Compact, Carbon-Neutral Design
# Inserted Apple, Amazon Earnings Preview: AI Capital Spending And iPhone Sales In Focus
# Inserted Is Apple (NASDAQ:AAPL) A Risky Investment?
# Inserted Looking for new activities? Google wants you to turn to its navigation app
# Inserted Apple Stocks Open Slightly Lower Ahead of Earnings
# Inserted Apple Stock Could Hit a New High After Earnings If All Goes Well
# Inserted Apple Has Had a Busy Week Coming Into Earnings
# Inserted XLK: Google's Q3 Shows Why Investors Must Own Tech Stocks
# Inserted Trending tickers: Microsoft, Meta, Starbucks, Super Micro and Stellantis
# Inserted Stock Market Today: Stocks slide on Mag 7 disappointment; Apple on deck
# Inserted Apple: Looking At Arguments For A Strong Earnings Report
# Inserted Apple, Amazon Take Spotlight in Mixed Week for Big Tech Earnings
# Inserted China's rising display industry could hurt US national security, report warns
# Inserted These Stocks Are Moving the Most Today: Microsoft, Meta, Super Micro, Coinbase, Carvana, Robinhood, Root, and Apple
# Inserted These Are the 3 Trillion-Dollar Stocks That Are in Warren Buffett's Portfolio
# Inserted Apple Earnings Are Nearly Here. This Is the Big Thing to Watch Today.
# Inserted Meetion Launches the iKey C210 Dual-Mode Apple Keyboard and Mouse Set
# Inserted China Economy Picks Up on Stimulus Push Ahead of US Election
# Inserted Apple is trying to sell loyal iPhone users on AI tools. Here's what Apple Intelligence can do
# Inserted Amazon and Apple earnings, PCE, mortgage rates: What to Watch
# Inserted Mag 7 earnings underline the group's huge market influence
# Inserted Apple Unveils New MacBook Pro Fresh Off Launch of Apple Intelligence
# Inserted Amazon/Apple Earnings Previews: Amazon Is A Little More Favored Here Than Apple
# Inserted Google Q3 Earnings Breakdown: Defending Search And Seeking New Growth Via AI
# Inserted Apple Launches New Macbook Pro Models With Powerful M4 Chips and Thunderbolt 5 Support
# Inserted Apple is challenging hackers to break into the company’s servers: If you’re successful, you could earn up to $1 million
# Inserted Apple Set to Reveal Record Quarterly Revenue, iPhone 16 Sales Surge in China
# Inserted Yahoo Finance Week in Tech: It’s all about earnings and Apple
# Inserted This Week in AI: A preview of Disrupt 2024's stacked AI panels
# Inserted Apple upgrades MacBook Pro with M4 chips
# Inserted Google's Q3 Results Prove YouTube Could Be Worth $750 Billion By 2027
# Inserted Apple's Q4 Earnings: Will Steady Services Offset Sluggish Mac Sales?
# Inserted Apple Unveils MacBook Pro With M4 Chip in Upgrade Frenzy
# Inserted Why investors should buy the Mag 7 'right now'
# Inserted Phunware Needs To Reignite Growth At All Costs
# Inserted What Lies in Store for Apple ETFs This Earnings Season?
# Inserted Apple launches new, more powerful versions of MacBook Pro
# Inserted Apple unveils new MacBook Pros and high-powered M4 Max chip as AI takes center stage
# Inserted Apple introduces M4 Pro and M4 Max
# Inserted Apple’s new MacBook Pro features the incredibly powerful M4 family of chips and ushers in a new era with Apple Intelligence
# Inserted Apple Intelligence is here. Early users are underwhelmed
# Inserted Apple launches new, more powerful versions of the MacBook Pro
# Inserted AMD: AI Pessimism Makes Little Sense
# Inserted Energy Additions, Not Transitions And Navigating A Trump Or Harris Win
# Inserted Decarbonization Stocks In Focus: Oklo And 5E Advanced Materials
# Inserted Amazon 3Q24: Strong Beat Overshadows Rising Temu Risk
# Inserted Buy 3 November Dogs Of The Dow And Watch 7 More
# Inserted Amazon: Road To $325
# Inserted The Noisiest 10 Days Of The Year
# Inserted S&P 500 Earnings: Fed May Likely Cut Fed Funds 25 Bps Next Thursday, November 7th
# Inserted As Stock Market Awaits Election, Palantir, S&P 500 Nuke Leaders Report
# Inserted Mag 7 earnings, election volatility, bitcoin: Market Takeaways
# Inserted Equity Markets Rise Amid Amazon Rally; Yields Jump
# Inserted Stocks Wrap Up Volatile Week With Gains
# Inserted AI Spending Dominated Big Tech Earnings. Why These 2 Stocks Got a Pass From Investors.
# Inserted Equity Markets Rise Amid Amazon Rally
# Inserted Amazon's Cloud and Ad Growth Boost Q3 Profit, Shares Surge 7.3%
# Inserted Amazon, IBD Stock of The Day, Jumps 6% As Earnings Beat Eases Investor Fears
# Inserted Stock Market Today: Indexes Fade Into The Close; Amazon Holds Above Buy Point (Live Coverage)
# Inserted US Equities Markets End Higher Friday
# Inserted Apple, Amazon, Intel, Boeing, Super Micro, Exxon, and More Stock Market Movers
# Inserted Amazon, Bezos, And 200 Bucks
# Inserted Equity Markets Higher Amid Amazon Rally
# Inserted Amazon Stock Today: Why This Iron Condor Could Make $178 Ahead Of The Elections
# Inserted Should Investors Chase the Rally in Amazon's Stock After Q3 Earnings?
# Inserted Amazon Gains as Q3 Operating Income Tops Forecasts; AWS Meets Expectations
# Inserted Amazon Web Services Margins Could Peak This Year After Hitting New High in Third Quarter, BofA Says
# Inserted Ecuador's Indigenous defenders face growing threats, activists say at UN summit
# Inserted What We Learned About AI From This Week's Big Tech Earnings
# Inserted Amazon’s CEO dropped a big hint about how a new AI version of Alexa is going to compete with chatbots like ChatGPT
# Inserted Midday stock movers: Amazon, Apple, Intel and more
# Inserted Amazon Rises the Most Since February After Earnings
# Inserted Tech Up After Amazon, Intel Earnings -- Tech Roundup
# Inserted Consumer Cos Up After Amazon Earnings -- Consumer Roundup
# Inserted Amazon’s S-team: Meet the 29 members who make up our senior leadership team
# Inserted S&P/TSX composite up nearly 100 points Friday, U.S. stock markets also higher
# Inserted Amazon Stock Jumps As Q3 Helps Ease What 'Everyone Was Worried About'
# Inserted Q3 2024 Amazon.com Inc Earnings Call
# Inserted Dow Rallies 400 Points; Apple Falls As Warren Buffett's Berkshire Hathaway Earnings Loom (Live Coverage)
# Inserted Why Amazon must 'keep spending' on AI
# Inserted Intel stock jumps on positive outlook, despite Q3 losses
# Inserted Stocks Rise After U.S. Added Just 12,000 Jobs in October
# Inserted Trump Vs. Harris: Top Stocks To Buy Or Avoid For The November 2024 Election
# Inserted Billionaire Ken Griffin Has Been Quietly Selling Microsoft and Buying This Chip Stock Instead. (Hint: It's not Nvidia.)
# Inserted Heard on the Street: Amazon's Strange Brew Proves Potent for Earnings
# Inserted Amazon stock pops after Q3 earnings beat
# Inserted October jobs report, Amazon and Apple, Boeing deal: 3 Things
# Inserted Amazon Q3 Earnings Surpass Estimates, Sales Increase Y/Y
# Inserted Amazon’s Cost Cuts Are Working: E-Comm Giant Nets $15 Billion Profit
# Inserted Amazon: A Machine From The Top Down
# Inserted Trending tickers: Apple, Amazon, Nvidia, Intel and Microsoft
# Inserted 5 Things to Know Before the Stock Market Opens
# Inserted Nvidia CEO Jensen Huang Is Bullish on Nuclear Power. Will Nvidia Invest in Nuclear Stocks?
# Inserted These Stocks Are Moving the Most Today: Apple, Amazon, Intel, Atlassian, Exxon, Chevron, and More
# Inserted Amazon Stock Pops 6% on Powerful Earnings Growth: 6 Key Metrics Investors Should See
# Inserted Oprah’s Favorite Things 2024: 10 unique small businesses to shop for holiday gifts in Amazon’s store
# Inserted Amazon shares rise sharply, broker raises target
# Inserted US added far fewer jobs than expected in October, Amazon & Intel lead tech stocks: Yahoo Finance
# Inserted AI Monthly: Soaring Costs Of GenAI Challenge Short-Term Profitability
# Inserted This Little-Known Company Has Outpaced All Of The "Magnificent Seven" Stocks This Year. Here's Why I Think It's Parabolic Run Could Just Be Getting Started.
# Inserted Amazon: Jefferies raises price target
# Inserted Amazon.com Inc (AMZN) Q3 2024 Earnings Call Highlights: Record Operating Income and Robust AWS ...
# Inserted Amazon's AI shopping assistant Rufus to more countries
# Inserted Amazon calms the horses, payrolls due
# Inserted Amazon com : Quarterly Report for Quarter Ending September 30, 2024 (Form 10-Q)
# Inserted Watch These Amazon Price Levels as Stock Jumps After Cloud Growth Drives Earnings Beat
# Inserted Amazon: EPS up by more than half in Q3
# Inserted Amazon's plan to tackle Temu, Shein? Sell more toothpaste
# Inserted Amazon.com (AMZN) Q3 2024 Earnings Call Transcript
# Inserted Amazon Q3 2024 Earnings Update
# Inserted Amazon com : Explore Amazon’s new Virtual Holiday Shop—an immersive 3D shopping experience that makes it easier to find the perfect gifts
# Inserted Amazon reports $158B in Q3 revenue, beats Wall Street expectations
# Inserted Amazon’s $110 billion cloud business is minting profits even amid the expensive Gen AI arms race—but for how long?
# Inserted Amazon CEO Says GenAI Is Growing Three Times Faster Than Cloud Computing Did
# Inserted Amazon Belt-Tightening Produces Strong Cloud, E-Commerce Results
# Inserted Markets Slide into Red on Halloween; Plus AAPL, AMZN, INTC Report
# Inserted Amazon’s Mammoth Q3 E-com and Cloud Business Impresses Wall Street
# Inserted Amazon CEO Andy Jassy hints at an 'agentic' Alexa
# Inserted Amazon Stock Moves Higher After Stronger-Than-Expected Earnings
# Inserted Amazon (AMZN) Reports Q3 Earnings: What Key Metrics Have to Say
# Inserted Amazon Stock Jumps As Cloud Business Powers Earnings Beat
# Inserted Amazon (AMZN) Surpasses Q3 Earnings and Revenue Estimates
# Inserted Why Amazon stock gains on earnings, unlike Meta and Microsoft
# Inserted Amazon Stock Climbs After a Big Earnings Beat. Spending Is Up Too.
# Inserted Amazon Tops Third-Quarter Views as Cloud Computing, Advertising Sales Gain
# Inserted Amazon beats third-quarter earnings expectations on strong cloud growth
# Inserted Amazon reports boost in quarterly profits, exceeds revenue estimates as it invests in AI
# Inserted Amazon Stock Jumps on Earnings Beat, Cloud Growth
# Inserted Amazon (NASDAQ:AMZN) Beats Q3 Sales Targets, Stock Soars
# Inserted Amazon's Q3 earnings report beats expectations; shares gain
# Inserted Will the Big Tech sell-off continue? This strategist says yes.
# Inserted Amazon.com, Inc. (AMZN) Q3 2024 Earnings Call Transcript
# Inserted Amazon Rival Set To Report Earnings After 103% Profit Surge
# Inserted Amazon stock jumps on Q3 earnings, guidance
# Inserted Nasdaq, S&P 500 sell off ahead of Amazon, Apple earnings
# Inserted Amazon Q3: Double Beat Makes Shares Jump
# Inserted Amazon.com, Inc. 2024 Q3 - Results - Earnings Call Presentation
# Inserted AI news at Amazon: The new Fire Tablet family, climate startup investments, and more
# Inserted Amazon Q3: 19% Growth In Ads And AWS
# Inserted Amazon Stock Slips Ahead Of Earnings On Cloud Concerns After Microsoft Report
# Inserted Tech Stocks: Staying Ahead Of The Curve
# Inserted Demand to return to office is ‘dismissing our humanity’, say Amazon staff
# Inserted Bond vigilantes flex muscles, tech tonic still fizzing
# Inserted Meta, Microsoft stocks tumble as Big Tech's AI splurge prompts investor caution
# Inserted Advertising revenue Amazon to 14.3 billion (+19%)
# Inserted Amazon Q3 earnings: Here’s what you need to know
# Inserted AMAZON COM : ANNOUNCES THIRD QUARTER RESULTS Form 8 K
# Inserted Elon Musk Slams Zoox Co-Founder Over FSD Criticism: Your Company 'Would Be Dead Already' If Not For Amazon
# Inserted Amazon: Q3 Earnings Snapshot
# Inserted The Zacks Analyst Blog Highlights Amazon.com, Johnson & Johnson, Boston Scientific and Armanino Foods of Distinction
# Inserted Amazon.com beats estimates for quarterly revenue
# Inserted Amazon.com Announces Third Quarter Results
# Inserted Heard on the Street: Etsy’s Crafty Niche Has Its Limits
# Inserted Amazon Earnings Are Imminent; Here Are The Recent Forecast Changes From Wall Street's Most Accurate Analysts
# Inserted Intel to report Q3 earnings as Wall Street looks for signs of improvements at chipmaker
# Inserted Amazon.com Inc (AMZN) Launches Rufus, AI-Powered Conversational Shopping Assistant, in Beta Across Europe Following Successful UK Debut
# Inserted Amazon Q3 earnings preview: AWS performance in focus as Big Tech goes all in on AI
# Inserted Amazon.com, Inc. (AMZN): Among The 10 Best S&P 500 Stocks to Buy According to Hedge Funds
# Inserted Apple, Amazon Earnings Preview: AI Capital Spending And iPhone Sales In Focus
# Inserted Here's Why We Think Amazon.com (NASDAQ:AMZN) Might Deserve Your Attention Today
# Inserted The Dow falls 250 points and the Nasdaq sinks 340 as Microsoft and Meta lead a tech stock selloff
# Inserted Here's Why Amazon (AMZN) is a Strong Growth Stock
# Inserted Apple, Amazon Take Spotlight in Mixed Week for Big Tech Earnings
# Inserted Roku stock tumbles after Q4 guidance disappoints, company says it will stop reporting key user figure
# Inserted Amazon and Apple, Peloton CEO, September PCE: 3 Things
# Inserted 3 Stocks That Have Generated Terrifying Returns for Investors Over the Past 5 Years
# Inserted 2 Warren Buffett Stocks That Could Beat the Market Through 2030
# Inserted XLK: Google's Q3 Shows Why Investors Must Own Tech Stocks
# Inserted Amazon workers 'appalled' by executive's claim that anyone was 'excited' about in-office mandate
# Inserted Trending tickers: Microsoft, Meta, Starbucks, Super Micro and Stellantis
# Inserted Google's Path To $200 Depends On This Missing Piece To Its AI Puzzle
# Inserted Meta and Microsoft: AI’s Spending Champs Won’t Be Tapping the Brakes
# Inserted Billionaires Are Buying Up This Millionaire-Maker Stock
# Inserted These Are the 3 Trillion-Dollar Stocks That Are in Warren Buffett's Portfolio
# Inserted Microsoft says Google running 'shadow campaigns' as Big Tech legal feud heats up
# Inserted Amazon Earnings Could be Mixed. Here’s the Bright Spot.
# Inserted Clouds gather over 'Mag 7' earnings
# Inserted Amazon and Apple earnings, PCE, mortgage rates: What to Watch
# Inserted Mag 7 earnings underline the group's huge market influence
# Inserted Top Stock Reports for Amazon.com, Johnson & Johnson and Boston Scientific
# Inserted Amazon/Apple Earnings Previews: Amazon Is A Little More Favored Here Than Apple
# Inserted Meta posts Q3 earnings beat, but stock falls on heavy spending plans
# Inserted Google Pops On Great Results, The Prospect Of Cloud Growth
# Inserted Amazon: Highest Upside Potential Of The Mag 7 Stocks
# Inserted Amazon com : 5 things to try on the new Kindle Colorsoft
# Inserted Amazon workers 'appalled' by AWS CEO's return to office remarks, urge policy reversal
# Inserted Amazon Says High Demand Is Clogging West Coast Fulfillment Centers
# Inserted Google Cloud 'knocked it out of the park.' Is Microsoft Azure next?
# Inserted Amazon com : When is Amazon's Cyber Monday 2024 sale? Here’s what you need to know about the big retail event.
# Inserted When Facebook became Meta, Big Tech's AI spending spree, and Elon Musk's robots: Tech news roundup
# Inserted Tech Earnings Fail to Fire Up Traders With Sky-High Expectations
# Inserted ChatGPT releases a search engine, an opening salvo in a brewing war with Google for dominance of the AI-powered internet
# Inserted Google's AI, Advertising & Autonomous Driving Capabilities Remain Dirt Cheap - Reiterate Buy
# Inserted Should You Buy Palantir Stock Before Monday's News? 2 Critical Things Investors Need to Know.
# Inserted 1 Big Reason Google Surged While Microsoft and Meta Fell After Earnings
# Inserted Decarbonization Stocks In Focus: Oklo And 5E Advanced Materials
# Inserted Microsoft Q1: A Rare Buying Opportunity Emerges
# Inserted The Noisiest 10 Days Of The Year
# Inserted S&P 500 Earnings: Fed May Likely Cut Fed Funds 25 Bps Next Thursday, November 7th
# Inserted FLTW: Long-Term Growth Prospect Intact, But Quite Expensive Now
# Inserted Why Elon Musk’s Robotaxi Dreams Are Premature
# Inserted From Search Engines to Answer Engines
# Inserted Dell Is Winning AI Server Market Share. Plus, Alphabet Cloud Growth, Shake Shack, and More Stocks.
# Inserted Mag 7 earnings, election volatility, bitcoin: Market Takeaways
# Inserted AI Spending Dominated Big Tech Earnings. Why These 2 Stocks Got a Pass From Investors.
# Inserted Top Research Reports for Alphabet, Booking & Union Pacific
# Inserted Tomasz Tunguz’s Theory Ventures has raised a $450 million second fund, filings say
# Inserted What We Learned About AI From This Week's Big Tech Earnings
# Inserted Amazon, Google show profit growth can quiet fears over heavy AI spending
# Inserted Jim Cramer Says That Alphabet Inc. (GOOGL) Reported An ‘Unambiguously Fantastic Quarter’
# Inserted Netflix has ‘won’ the streaming wars — here’s how others will compete
# Inserted Microsoft, Amazon or Alphabet: Who Is Winning the Cloud Race?
# Inserted Anxious Google employees just broached cost-cutting concerns with executives—who were dressed in Halloween costumes
# Inserted Uber's Q3 Review: Analysts See Opportunity Amid Growth Slowdown, Strong Margins, And Expanding Autonomous Vehicle Partnerships
# Inserted 'I'm Not Kidding, Reddit Was Amazing' — Jim Cramer Compares Reddit To Google, Saying Choosing Between Them Isn't Easy
# Inserted Stock Market Retreats Before Election Day; Microsoft, Apple, Amazon, Google, Meta In Focus: Weekly Review
# Inserted Alphabet Inc. (GOOG) Beats Q3 Estimates Driven by 35% Growth in Cloud Revenue, Highlights AI’s Role in Productivity and Innovation
# Inserted LendingTree Inc (TREE) Q3 2024 Earnings Call Highlights: Record Insurance Revenue and Strong ...
# Inserted Indonesia Blocks Google's Pixel Smartphones Over Local Content Rules, Following iPhone 16 Ban
# Inserted Big Tech's AI spending spree has Wall Street worried
# Inserted Stocks Rise After U.S. Added Just 12,000 Jobs in October
# Inserted Trump Vs. Harris: Top Stocks To Buy Or Avoid For The November 2024 Election
# Inserted Amazon stock pops after Q3 earnings beat
# Inserted Google Post Q3: Now A Strong Buy
# Inserted OpenAI Launches ChatGPT Web Search. Is Google Stock A Buy Or Sell?
# Inserted OpenAI Adds Search Engine to ChatGPT, Challenging Google
# Inserted Q3 2024 Marin Software Inc Earnings Call
# Inserted Tech Giants Are Set to Spend $200 Billion This Year Chasing AI
# Inserted Amazon Web Services is minting profits
# Inserted OpenAI adds smarter web search function to ChatGPT
# Inserted AI Monthly: Soaring Costs Of GenAI Challenge Short-Term Profitability
# Inserted After iPhone 16s, Indonesia Blocks Google Pixel Phones: Kontan
# Inserted Australia’s Wealth Fund Says Volatile Inflation Clouds Rate Path
# Inserted Is Alphabet's (GOOGL) Stock Due for Another Bounce After Strong Q3 Results?
# Inserted Apple Could Be Bailed Out by Services and India After Guidance Disappoints
# Inserted Amazon Stock Climbs After a Big Earnings Beat. Spending Is Up Too.
# Inserted Russian court fines Google $2,000,000,000,000,000,000,000,000,000,000,000 for blocking YouTube content
# Inserted Google Maps Adds AI-Powered Navigation Updates and Enhanced Immersive View for 150 Cities
# Inserted ChatGPT will now work as a search engine as OpenAI partners with some news outlets
# Inserted Will the Big Tech sell-off continue? This strategist says yes.
# Inserted Should You Forget Nvidia and Buy These 2 Artificial Intelligence (AI) Stocks Instead?
# Inserted Google Searches For Another All-Time High
# Inserted Sector Update: Tech Stocks Fall Late Afternoon
# Inserted Amazon Q3: Double Beat Makes Shares Jump
# Inserted OpenAI launches ChatGPT search in direct challenge to Google’s search empire
# Inserted Alphabet Inc. (GOOG): Among The 10 Best S&P 500 Stocks to Buy According to Hedge Funds
# Inserted Nvidia stock sinks on fears of AI spending slowdown
# Inserted Squirrelly Action Is One Reason To Watch Nvidia. Here Are 5 More.
# Inserted Tech Stocks: Staying Ahead Of The Curve
# Inserted Alphabet’s Waymo Valued Above $45 Billion After Funding
# Inserted Google's Gemini API and AI Studio get grounding with Google Search
# Inserted OpenAI launches its search engine to compete with Google
# Inserted OpenAI launches its Google challenger, ChatGPT Search
# Inserted Google Maps is getting new AI features powered by Gemini
# Inserted Uber Technologies (UBER) Q3 2024 Earnings Call Transcript
# Inserted OpenAI Brings Search Features to ChatGPT in Challenge to Google
# Inserted The Zacks Analyst Blog Highlights Alphabet, IXP, FCOM, VOX and XLC
# Inserted Microsoft Corporation (MSFT) Expands GitHub Copilot’s AI Capabilities, Introducing Multi-Model Support with Anthropic and Google Alternatives to OpenAI
# Inserted Alphabet Inc. (GOOG) Expands ‘AI Overviews’ to Over 100 Countries, Enhancing Global Search Capabilities with Generative AI
# Inserted Zacks Earnings Trends Highlights: Tesla, Alphabet and Microsoft
# Inserted Uber is transitioning into a 'software company': Investor
# Inserted Google brings AI answers to map applications
# Inserted Alphabet's Artificial Intelligence Push Gains Momentum. Is Google Stock A Buy?
# Inserted Looking for new activities? Google wants you to turn to its navigation app
# Inserted Alphabet Inc. (NASDAQ:GOOG): Among 10 Best Fundamental Stocks to Invest In
# Inserted Nvidia: You Haven't Seen Anything Yet
# Inserted XLK: Google's Q3 Shows Why Investors Must Own Tech Stocks
# Inserted Google’s dominance quiets worries over AI spending: Morning Brief
# Inserted Heavy AI Spending Drags Google's Margins
# Inserted Google's Path To $200 Depends On This Missing Piece To Its AI Puzzle
# Inserted Apple, Amazon Take Spotlight in Mixed Week for Big Tech Earnings
# Inserted Alphabet: Growth In Google Cloud Vindicates The AI Spend
# Inserted Google Q3 Earnings: Perplexity Is Not A Threat
# Inserted Microsoft says Google running 'shadow campaigns' as Big Tech legal feud heats up
# Inserted Q3 2024 Chemed Corp Earnings Call
# Inserted Election Brings One Certainty for Tech Stocks—More Uncertainty
# Inserted Decoding Alphabet Inc (GOOGL): A Strategic SWOT Insight
# Inserted Amazon Earnings Could be Mixed. Here’s the Bright Spot.
# Inserted Google Confirms $2.7 Billion Deal to Hire Character Co-Founders
# Inserted Tech Flexes Earnings Power: A Closer Look
# Inserted Google Cloud Rolls Out Axion-Based C4A VMs for Improved Performance
# Inserted Meta Reports Record Revenue, Slower Digital Advertising Growth
# Inserted Microsoft and Alphabet’s latest earnings show once again that it’s all about the cloud
# Inserted Nvidia Stock Falls. Why Alphabet, AMD Earnings Are Giving Mixed Signals.
# Inserted Mag 7 earnings underline the group's huge market influence
# Inserted Microsoft Cloud Fuels Stronger-Than-Expected Revenue Growth
# Inserted Reddit CEO: We are becoming mainstream social media
# Inserted Dow Falls As Super Micro Crashes; Meta Dives As Microsoft Gains After Results (Live Coverage)
# Inserted Microsoft’s (NASDAQ:MSFT) Q3 Sales Beat Estimates
# Inserted These Stocks Moved the Most Today: Super Micro, Alphabet, AMD, Lilly, Reddit, AbbVie, Qorvo, Garmin, and More
# Inserted Meta posts Q3 earnings beat, but stock falls on heavy spending plans
# Inserted Microsoft beats on Q1 top and bottom lines on cloud strength
# Inserted Yacktman Asset Management's Strategic Moves in Q3 2024: A Closer Look at Alphabet Inc's Impact
# Inserted A Russian court fined Google more money than the world's GDP
# Inserted Google Q3 Earnings Breakdown: Defending Search And Seeking New Growth Via AI
# Inserted Alphabet Q3 Commentary on AI Counters Bear Case, RBC Capital Markets Says
# Inserted Alphabet Shares Jump 7% as Strong Q3 Results Highlight Google Cloud and AI Momentum
# Inserted Alphabet Up 7% With Explosive Q3: AI-Fueled Revenue Surge And Massive Dividend
# Inserted Alphabet Earnings Had Wall Street on Edge. There Was No Need to Fret.
# Inserted Why Alphabet (GOOGL) Stock Is Up Today
# Inserted Jim Cramer Says Google's AI Investment Next Year 'Should Be Fabulous For Nvidia'
# Inserted ‘There are no guardrails.’ This mom believes an AI chatbot is responsible for her son’s suicide
# Inserted Google Pops On Great Results, The Prospect Of Cloud Growth
# Inserted Nvidia: Forward Earnings Looking More Uncertain
# Inserted Yahoo Finance Week in Tech: It’s all about earnings and Apple
# Inserted Google stock jumps 4% after AI momentum drives earnings
# Inserted This Week in AI: A preview of Disrupt 2024's stacked AI panels
# Inserted Alphabet's Q3 Report May Settle Questions About CapEx, Return on Invested Capital, UBS Says
# Inserted Why Analysts Are Bullish on Google Parent Alphabet After Earnings
# Inserted Alphabet Inc. (GOOG): A Bull Case Theory
# Inserted Google Bought YouTube For $1.65B And Now It Prints $50B In One Year — Sundar Pichai Says Alphabet 'Leaning Into The Living Room Experience'
# Inserted Google's Q3 Results Prove YouTube Could Be Worth $750 Billion By 2027
# Inserted Top Stock Movers Now: Alphabet, Garmin, Snap, and More
# Inserted Dow Jones Adds To Gains; Warren Buffett Stock Dives As Supermicro Crashes (Live Coverage)
# Inserted Why investors should buy the Mag 7 'right now'
# Inserted Alphabet says Spotify, Paramount sign to use new cloud chip
# Inserted Can Solid Q3 Earnings Beat & Encouraging View Push GOOGL Stock Higher?
# Inserted Top Midday Stories: Google Reports Better-Than-Expected Q3 Earnings; Ernst & Young Resigns as Super Micro's Accounting Firm
# Inserted Wall Street Lunch: Super Micro Computer Loses 30%
# Inserted Over 25% of Google’s code is now written by AI—and CEO Sundar Pichai says it’s just the start
# Inserted Reddit Surges to New High After Strong Holiday-Quarter Forecast
# Inserted The Dow jumps 150 points as strong earnings and GDP growth boost stocks
# Inserted These Stocks Are Moving the Most Today: Alphabet, AMD, Reddit, Snap, First Solar, Qorvo, Microsoft, and More
# Inserted Reddit Rides Earnings High, Rising 36%
# Inserted Stocks to Watch Wednesday: AMD, Alphabet, Reddit, Snap
# Inserted Google's capex spending is growing 60%, which is good news for NVIDIA
# Inserted Google's Waymo Should Make It The Most Valuable Company
# Inserted A New Buy Point Is Just One Reason To Watch Nvidia. Here Are 5 More.
# Inserted Google Cloud 'knocked it out of the park.' Is Microsoft Azure next?
# Inserted Google: AI Leads The Way Higher
# Inserted Google Big Earnings Pop (Technical Analysis)
# Inserted Google: Why I'm Still Bullish After The Post-Earnings Surge
# Inserted Tesla Rocks, But They Are Behind Waymo With Robotaxis
# Inserted S&P 500: Mean Reversion Always Wins In The End
# Inserted Snap Q3 Earnings Review: My Opportunistic Call Has Finally Run Its Course (Rating Downgrade)
# Inserted Google's AI-fuelled gains in cloud bode well for Amazon, Microsoft
# Inserted Google's Strong Q3 Earnings: What It Means For Your Portfolio Strategy
# Inserted Only 10 Companies Have Reached a Trillion-Dollar Market Cap -- This Is the 1 That's a Screaming Buy Right Now
# Inserted A 'lot rides' on Big Tech earnings amid two busy weeks for markets
# Inserted Google Gets No Respect From Wall Street: Still The Best Buy In Tech
# Inserted Alphabet Inc (GOOG) Q3 2024 Earnings Call Highlights: Strong Revenue Growth and AI Advancements
# Inserted Digital clones of Brianna Ghey and Molly Russell created by ‘manipulative and dangerous’ AI
# Inserted 1 Big Reason Google Surged While Microsoft and Meta Fell After Earnings
# Inserted Decarbonization Stocks In Focus: Oklo And 5E Advanced Materials
# Inserted Microsoft Q1: A Rare Buying Opportunity Emerges
# Inserted The Noisiest 10 Days Of The Year
# Inserted From Search Engines to Answer Engines
# Inserted Dell Is Winning AI Server Market Share. Plus, Alphabet Cloud Growth, Shake Shack, and More Stocks.
# Inserted Mag 7 earnings, election volatility, bitcoin: Market Takeaways
# Inserted AI Spending Dominated Big Tech Earnings. Why These 2 Stocks Got a Pass From Investors.
# Inserted Top Research Reports for Alphabet, Booking & Union Pacific
# Inserted Tomasz Tunguz’s Theory Ventures has raised a $450 million second fund, filings say
# Inserted What We Learned About AI From This Week's Big Tech Earnings
# Inserted Amazon, Google show profit growth can quiet fears over heavy AI spending
# Inserted Jim Cramer Says That Alphabet Inc. (GOOGL) Reported An ‘Unambiguously Fantastic Quarter’
# Inserted Netflix has ‘won’ the streaming wars — here’s how others will compete
# Inserted Microsoft, Amazon or Alphabet: Who Is Winning the Cloud Race?
# Inserted Anxious Google employees just broached cost-cutting concerns with executives—who were dressed in Halloween costumes
# Inserted Uber's Q3 Review: Analysts See Opportunity Amid Growth Slowdown, Strong Margins, And Expanding Autonomous Vehicle Partnerships
# Inserted 'I'm Not Kidding, Reddit Was Amazing' — Jim Cramer Compares Reddit To Google, Saying Choosing Between Them Isn't Easy
# Inserted Stock Market Retreats Before Election Day; Microsoft, Apple, Amazon, Google, Meta In Focus: Weekly Review
# Inserted Q3 earnings showcase AI winners and losers
# Inserted Alphabet Inc. (GOOG) Beats Q3 Estimates Driven by 35% Growth in Cloud Revenue, Highlights AI’s Role in Productivity and Innovation
# Inserted LendingTree Inc (TREE) Q3 2024 Earnings Call Highlights: Record Insurance Revenue and Strong ...
# Inserted Indonesia Blocks Google's Pixel Smartphones Over Local Content Rules, Following iPhone 16 Ban
# Inserted Big Tech's AI spending spree has Wall Street worried
# Inserted Stocks Rise After U.S. Added Just 12,000 Jobs in October
# Inserted Trump Vs. Harris: Top Stocks To Buy Or Avoid For The November 2024 Election
# Inserted Amazon stock pops after Q3 earnings beat
# Inserted Google Post Q3: Now A Strong Buy
# Inserted OpenAI Launches ChatGPT Web Search. Is Google Stock A Buy Or Sell?
# Inserted Q3 2024 Marin Software Inc Earnings Call
# Inserted Amazon Web Services is minting profits
# Inserted OpenAI adds smarter web search function to ChatGPT
# Inserted AI Monthly: Soaring Costs Of GenAI Challenge Short-Term Profitability
# Inserted Is Google Parent Alphabet the Best "Magnificent Seven" Stock to Buy Right Now?
# Inserted ChatGPT takes on Google, Meta's spending spree, and Microsoft's data center problem: AI news roundup
# Inserted Meet the Unstoppable Stock That Could Join Apple, Nvidia, and Microsoft in the $3 Trillion Club Next Year
# Inserted Meet the Supercharged Growth Stock That Could Join Apple, Nvidia, Microsoft, and Alphabet in the $2 Trillion Club by 2028
# Inserted This Little-Known Company Has Outpaced All Of The "Magnificent Seven" Stocks This Year. Here's Why I Think It's Parabolic Run Could Just Be Getting Started.
# Inserted CEOs are doing the best they can to to avoid discussing politics this earnings season
# Inserted Thailand Approves $2 Billion of Investments in Data Centers, Electronics
# Inserted North American Morning Briefing : Tech Steadies as Traders Await Jobs Report
# Inserted Indonesia bans sales of Google phones days after blocking Apple's iPhone 16
# Inserted OpenAI Adds Search Engine to ChatGPT, Challenging Google
# Inserted After iPhone 16s, Indonesia Blocks Google Pixel Phones: Kontan
# Inserted Thailand approves $2 billion worth of investments in data centres, electronics
# Inserted Australia’s Wealth Fund Says Volatile Inflation Clouds Rate Path
# Inserted Is Alphabet's (GOOGL) Stock Due for Another Bounce After Strong Q3 Results?
# Inserted Apple Could Be Bailed Out by Services and India After Guidance Disappoints
# Inserted Russian court fines Google $2,000,000,000,000,000,000,000,000,000,000,000 for blocking YouTube content
# Inserted Google Maps Adds AI-Powered Navigation Updates and Enhanced Immersive View for 150 Cities
# Inserted Amazon Stock Climbs After a Big Earnings Beat. Spending Is Up Too.
# Inserted OpenAI launches its Google challenger, ChatGPT Search
# Inserted ChatGPT will now work as a search engine as OpenAI partners with some news outlets
# Inserted Google Maps is getting new AI features powered by Gemini
# Inserted Will the Big Tech sell-off continue? This strategist says yes.
# Inserted Should You Forget Nvidia and Buy These 2 Artificial Intelligence (AI) Stocks Instead?
# Inserted Squirrelly Action Is One Reason To Watch Nvidia. Here Are 5 More.
# Inserted Google Searches For Another All-Time High
# Inserted Sector Update: Tech Stocks Fall Late Afternoon
# Inserted Amazon Q3: Double Beat Makes Shares Jump
# Inserted OpenAI launches ChatGPT search in direct challenge to Google’s search empire
# Inserted Alphabet Inc. (GOOG): Among The 10 Best S&P 500 Stocks to Buy According to Hedge Funds
# Inserted Nvidia stock sinks on fears of AI spending slowdown
# Inserted Tech Stocks: Staying Ahead Of The Curve
# Inserted Alphabet’s Waymo Valued Above $45 Billion After Funding
# Inserted Google's Gemini API and AI Studio get grounding with Google Search
# Inserted OpenAI launches its search engine to compete with Google
# Inserted Uber Technologies (UBER) Q3 2024 Earnings Call Transcript
# Inserted OpenAI Brings Search Features to ChatGPT in Challenge to Google
# Inserted Microsoft Corporation (MSFT) Expands GitHub Copilot’s AI Capabilities, Introducing Multi-Model Support with Anthropic and Google Alternatives to OpenAI
# Inserted Alphabet Inc. (GOOG) Expands ‘AI Overviews’ to Over 100 Countries, Enhancing Global Search Capabilities with Generative AI
# Inserted Uber is transitioning into a 'software company': Investor
# Inserted Google brings AI answers to map applications
# Inserted Alphabet's Artificial Intelligence Push Gains Momentum. Is Google Stock A Buy?
# Inserted Looking for new activities? Google wants you to turn to its navigation app
# Inserted Alphabet Inc. (NASDAQ:GOOG): Among 10 Best Fundamental Stocks to Invest In
# Inserted Google defeats UK trademark lawsuit over YouTube Shorts name
# Inserted Google Maps adds AI features to help users explore and navigate the world around them
# Inserted Stock Market News for Oct 31, 2024
# Inserted 1 Electric Vehicle ETF to Buy With 2025 Around the Corner
# Inserted Legendary billionaire tech investor makes an amazing claim about Nvidia's stock
# Inserted Russia fines Google $20,000,000,000,000,000,000,000,000,000,000,000
# Inserted Nvidia: You Haven't Seen Anything Yet
# Inserted XLK: Google's Q3 Shows Why Investors Must Own Tech Stocks
# Inserted Where Will IonQ Be in 3 Years?
# Inserted Alphabet price target raised to $192 from $187 at UBS
# Inserted Russia fines Google 2.5 decillion dollars for YouTube bans—eclipsing global GDP
# Inserted Startups Get Their Own DC Advocate With Y Combinator’s Luther Lowe
# Inserted A Russian court fined Google more money than the world's GDP
# Inserted Trending tickers: Microsoft, Meta, Starbucks, Super Micro and Stellantis
# Inserted Google’s dominance quiets worries over AI spending: Morning Brief
# Inserted Heavy AI Spending Drags Google's Margins
# Inserted Google's Path To $200 Depends On This Missing Piece To Its AI Puzzle
# Inserted Apple, Amazon Take Spotlight in Mixed Week for Big Tech Earnings
# Inserted Alphabet: Growth In Google Cloud Vindicates The AI Spend
# Inserted Microsoft Cloud Fuels Stronger-Than-Expected Revenue Growth
# Inserted Google Q3 Earnings: Perplexity Is Not A Threat
# Inserted Microsoft says Google running 'shadow campaigns' as Big Tech legal feud heats up
# Inserted Q3 2024 Chemed Corp Earnings Call
# Inserted Election Brings One Certainty for Tech Stocks—More Uncertainty
# Inserted Decoding Alphabet Inc (GOOGL): A Strategic SWOT Insight
# Inserted Amazon Earnings Could be Mixed. Here’s the Bright Spot.
# Inserted Google Confirms $2.7 Billion Deal to Hire Character Co-Founders
# Inserted Tech Flexes Earnings Power: A Closer Look
# Inserted Google Cloud Rolls Out Axion-Based C4A VMs for Improved Performance
# Inserted Meta Reports Record Revenue, Slower Digital Advertising Growth
# Inserted Alphabet Earnings Had Wall Street on Edge. There Was No Need to Fret.
# Inserted Microsoft and Alphabet’s latest earnings show once again that it’s all about the cloud
# Inserted Mag 7 earnings underline the group's huge market influence
# Inserted Reddit CEO: We are becoming mainstream social media
# Inserted Google Q3 Earnings Breakdown: Defending Search And Seeking New Growth Via AI
# Inserted Google Pops On Great Results, The Prospect Of Cloud Growth
# Inserted Google's Q3 Results Prove YouTube Could Be Worth $750 Billion By 2027
# Inserted Top Midday Stories: Google Reports Better-Than-Expected Q3 Earnings; Ernst & Young Resigns as Super Micro's Accounting Firm
# Inserted Wall Street Lunch: Super Micro Computer Loses 30%
# Inserted The Dow jumps 150 points as strong earnings and GDP growth boost stocks
# Inserted Dow Jones Rises After Economic Data; Warren Buffett Stock Dives As Nvidia Rival Falls (Live Coverage)
# Inserted 2 Tech Stocks To Watch In November 2024
# Inserted Stocks to Watch Wednesday: AMD, Alphabet, Reddit, Snap
# Inserted Google's capex spending is growing 60%, which is good news for NVIDIA
# Inserted Google's Waymo Should Make It The Most Valuable Company
# Inserted A New Buy Point Is Just One Reason To Watch Nvidia. Here Are 5 More.
# Inserted Google Cloud 'knocked it out of the park.' Is Microsoft Azure next?
# Inserted Alphabet Q3 results beat analyst estimates as cloud revenue soars; shares jump
# Inserted Why Alphabet (GOOGL) is a Top Momentum Stock for the Long-Term
# Inserted Nvidia Stock Falls. Why Alphabet, AMD Earnings Are Giving Mixed Signals.
# Inserted These Stocks Are Moving the Most Today: Alphabet, AMD, Reddit, Snap, First Solar, Qorvo, Microsoft, and More
# Inserted Stocks open mixed as Big Tech earnings rollout continues
# Inserted Google Earnings Beat: How 'AI Overviews' Is Boosting Internet Search Advertising
# Inserted Alphabet’s Pricey AI Bet Pays Off With Cloud, Search Growth
# Inserted ‘There are no guardrails.’ This mom believes an AI chatbot is responsible for her son’s suicide
# Inserted Microsoft and Meta, Eli Lilly, US GDP in Q3: 3 Things
# Inserted Strong Alphabet Earnings Underpin Investor Sentiment as US Equity Futures Tread Water Pre-Bell
# Inserted Shein Brings The Children’s Place to Its Marketplace Platform
# Inserted Google: AI Leads The Way Higher
# Inserted Google Big Earnings Pop (Technical Analysis)
# Inserted Meta to report Q3 earnings with AI, ad sales in focus
# Inserted Alphabet says Spotify, Paramount sign to use new cloud chip
# Inserted Trump's threats to prosecute opponents, election workers, and Google
# Inserted Google: Why I'm Still Bullish After The Post-Earnings Surge
# Inserted Tesla Rocks, But They Are Behind Waymo With Robotaxis
# Inserted EWZ: A Cautionary Tale Of Fiscal Struggles And Currency Chaos
# Inserted JPMorgan to Pay $151 Million to Settle SEC Charges In Multiple Enforcement Actions
# Inserted Trump Vs. Harris: Top Stocks To Buy Or Avoid For The November 2024 Election
# Inserted JPMorgan Chase : Financial report - JPMORGAN CHASE & CO.
# Inserted JPMorgan to pay $151M over flawed investment disclosures, more
# Inserted Update: JPMorgan Chase Pays $151 Million to Settle Five SEC Charges
# Inserted JPMorgan Chase Pays $151 Million to Settle Five SEC Charges
# Inserted CEOs are doing the best they can to to avoid discussing politics this earnings season
# Inserted 2 Financial Juggernauts Deliver Results And Dividends
# Inserted JPMorgan Pays $151 Million to Settle Slate of SEC Complaints
# Inserted JPMorgan to Pay $151 Million for Alleged Misleading Disclosures, Other Charges
# Inserted JPMorgan Chase reaches $100 million settlement with SEC over disclosures
# Inserted J.P. Morgan to Pay $151 Million for Alleged Misleading Disclosures, Other Charges
# Inserted JPMorgan hires Rajendram from Deutsche Bank as head of EMEA consumer deals
# Inserted Is JPMorgan Diversified Return Emerging Markets Equity ETF (JPEM) a Strong ETF Right Now?
# Inserted Decoding JPMorgan Chase & Co (JPM): A Strategic SWOT Insight
# Inserted Ex-JPMorgan Adviser Agrees to Temporarily Halt Client Poaching
# Inserted JPMorganChase Files Form 10-Q for the Quarter Ended September 30, 2024
# Inserted JPMorgan Chase : Beneficial Ownership Report - Form SC 13G
# Inserted BofA discloses Zelle probe, says it may result in litigation
# Inserted Florida Accidentally Banned Banks From Doing Business in Sunshine State
# Inserted Wall Street Breakfast Podcast: Reddit Gets An Upvote From Investors
# Inserted JPMorgan Sues Four Customers Seen in Viral TikToks Over Fraud Allegations
# Inserted Goldman, JPMorgan Traders Bid for Slice of Thames’ Proposed Debt
# Inserted Wall Street bosses are more worried about inflation than the US election
# Inserted JPMorgan Chase Sues Four Customers for Bank Fraud Seen in Viral TikToks
# Inserted JPMorgan Chase (NYSE:JPM) Ticks All The Boxes When It Comes To Earnings Growth
# Inserted JPMorgan Chase sues bank customers over stolen money via TikTok 'glitch' video
# Inserted JPMorgan is suing the customers who cashed in on bank’s ‘infinite money glitch’
# Inserted 3 Passive Income ETFs for Your Retirement Strategy
# Inserted Why Janet Yellen wants more Americans to have a bank account
# Inserted Harris Or Trump? How The Next President Could Change The Game For Stocks, Taxes, And Inflation
# Inserted People who allegedly withdrew thousands of dollars from Chase ATMs in viral check fraud scheme may soon have to pay up
# Inserted JPMorgan Reportedly Sues Customers for 'Infinite Free Money Glitch'
# Inserted JPMorgan sues customers over check fraud linked to glitch that went viral
# Inserted JPMorgan is suing people who used an 'infinite money glitch' to steal thousands of dollars
# Inserted Jamie Dimon slams US regulators: 'It's time to fight back'
# Inserted JPMorgan's Barry Sees Steeper Yield Curves Ahead
# ...
# Inserted Trending tickers: Apple, Amazon, Nvidia, Intel and Microsoft
# Inserted The Zacks Analyst Blog Palantir Technologies, NVIDIA and SoundHound AI
# Inserted NVIDIA Trading at a Low P/E Multiple: Time to Buy the Stock?
# Inserted Nvidia CEO Jensen Huang Is Bullish on Nuclear Power. Will Nvidia Invest in Nuclear Stocks?
# Inserted Super Micro Computer: Important Thesis Update After Auditor Resignation (Downgrade)
# Inserted Prediction: 1 Stock That'll Be Worth More Than Nvidia 5 Years From Now
# Inserted Did AMD Just Give a Big Reason to Buy Nvidia Stock Hand Over Fist?
# Inserted Intel: Outlook Too Easy To Miss, Buy For The Honeymoon Phase
# Inserted Is Google Parent Alphabet the Best "Magnificent Seven" Stock to Buy Right Now?
# Inserted AI Data Center Deep Dive - Navigating The Data Center Value Chain
# Inserted AMD's Q3 Signals Accelerated AI Push With Record Data Center Revenue
# Inserted Nvidia Stock Rises Following Amazon, Intel Earnings. It’s Still Set to End the Week Down.
# Inserted Billionaires John Overdeck and David Siegel Are Piling Into Artificial Intelligence (AI) Titan Nvidia and Dumping Shares of This Warren Buffett Favorite
# Inserted Meet the Unstoppable Stock That Could Join Apple, Nvidia, and Microsoft in the $3 Trillion Club Next Year
# Inserted Meet the Supercharged Growth Stock That Could Join Apple, Nvidia, Microsoft, and Alphabet in the $2 Trillion Club by 2028
# Inserted This Little-Known Company Has Outpaced All Of The "Magnificent Seven" Stocks This Year. Here's Why I Think It's Parabolic Run Could Just Be Getting Started.
# Inserted Arm Stock vs. Taiwan Semiconductor Stock: Wall Street Says Buy One and Sell the Other
# Inserted China's sanction-hit tech industry puzzles over impact of Trump, Harris presidencies
# Inserted Post-Election Risks? What Chip Companies And A Railroad Could Signal At Upcoming Analyst Days​
# Inserted Intel CEO calls TSMC an 'awesome' company, says the company is still waiting for CHIPS Act money
# Inserted AMD: Q3 Earnings Reset Expectations, Growth Acceleration Phase Warrants Higher Valuation
# Inserted This Nvidia Partner Is Now The S&P 500's Biggest Loser In 2024
# Inserted Nvidia Shares Slip as Super Micro's Stock Declines Amid Auditor Resignation, Market Pressures
# Inserted Nvidia Stock Falls. Why Meta, Microsoft Earnings Are Giving Investors a Halloween Fright.
# Inserted Will the Big Tech sell-off continue? This strategist says yes.
# Inserted Nvidia's Hiccup Reveals The 8 'Secrets' Of Selling. No. 2 Is Key.
# Inserted Should You Forget Nvidia and Buy These 2 Artificial Intelligence (AI) Stocks Instead?
# Inserted Squirrelly Action Is One Reason To Watch Nvidia. Here Are 5 More.
# Inserted Nvidia Is Falling Today -- Is This an Opportunity to Buy the Artificial Intelligence (AI) Stock?
# Inserted NVIDIA Corporation (NVDA): Among The 10 Best S&P 500 Stocks to Buy According to Hedge Funds
# Inserted Why Monolithic Power Systems Plunged Today
# Inserted Masayoshi Son's Missed $15 Billion Opportunity: Nvidia Stake Would Have Skyrocketed
# Inserted Nvidia Stock Drops as Market Uncertainty and Tech Sector Pressure Increase
# Inserted Nvidia-Run:ai deal to be reviewed under EU's merger rules
# Inserted Nvidia stock sinks on fears of AI spending slowdown
# Inserted Tech Stocks: Staying Ahead Of The Curve
# Inserted Why Nvidia Stock Is Sinking Today
# Inserted Meta, Microsoft stocks tumble as Big Tech's AI splurge prompts investor caution
# Inserted Nvidia and other AI stocks are getting dragged down by Microsoft and Meta
# Inserted Micron Stock Has Ridden the Nvidia Wave. It Now Faces This Big Threat.
# Inserted Nvidia: You Haven't Seen Anything Yet
# Inserted Nvidia: EU examines proposed acquisition of Run Labs
# Inserted Nvidia: Self-Driving Vehicles Are An Important Proof Point
# Inserted 2 Top Stocks That Can Supercharge Your Portfolio in 2025 and Beyond
# Inserted Google's Path To $200 Depends On This Missing Piece To Its AI Puzzle
# Inserted AMD Q3: Buy The Dip As Data Center Growth Is What Counts
# Inserted Billionaire Philippe Laffont of Coatue Is Dumping Shares of Nvidia and Palantir and Piling Into This Artificial Intelligence (AI) Infrastructure Juggernaut
# Inserted 1 Spectacular BlackRock ETF to Buy Ahead of the Russell 2000 Bull Market
# Inserted Nvidia Generated Nearly $50 Billion Thanks to Selling AI Products and Services This Year. But Here's Another -- and Completely Different -- Way AI Will Supercharge the Company's Earnings.
# Inserted Nvidia's proposed buy of AI startup Run: ai requires EU approval, EU regulators say
# Inserted Dow Jones Futures Fall As Microsoft, Meta Slide On Guidance; Robinhood, Crypto Plays Skid
# Inserted Samsung Sees Progress in Memory Chips for AI After Delays
# Inserted Taiwan Q3 preliminary GDP beats forecast on solid AI demand
# Inserted Q3 2024 Parade Technologies Ltd Earnings Call
# Inserted SoftBank CEO Sees $9 Trillion in AI Spending, Nvidia Stock Undervalued
# Inserted Dow Jones Futures: Microsoft, Meta Earnings Beat; Robinhood Dives, Crypto Plays Fall
# Inserted Nvidia (NVDA) Declines More Than Market: Some Information for Investors
# Inserted AI’s $1.3 Trillion Future Increasingly Hinges on Taiwan
# Inserted Nvidia Stock Falls. Why Alphabet, AMD Earnings Are Giving Mixed Signals.
# Inserted Mag 7 earnings underline the group's huge market influence
# Inserted NVIDIA Sets Conference Call for Third-Quarter Financial Results
# Inserted A New Buy Point Is Just One Reason To Watch Nvidia. Here Are 5 More.
# Inserted AMD Tumbles After AI Chip Growth Fails to Inspire Investors
# Inserted Tech Earnings Have Begun With Google, AMD and More. Here Are 3 Early Takeaways.
# Inserted Do Fund Managers Love Or Hate NVIDIA Corporation (NVDA)?
# Inserted OpenAI Collaborates With Broadcom, TSMC, and Adds AMD Chips as It Diversifies Beyond Nvidia
# Inserted Why AMD (AMD) Stock Is Falling Today
# Inserted Jim Cramer Says Google's AI Investment Next Year 'Should Be Fabulous For Nvidia'
# Inserted Nvidia: Forward Earnings Looking More Uncertain
# Inserted How to Play Mag 7 Earnings
# Inserted Why investors should buy the Mag 7 'right now'
# Inserted Nvidia (NVDA) Upgraded to Buy: Here's What You Should Know
# Inserted Ditch AMD and 'just go with the pure play' Nvidia
# Inserted This Stock May Be the Big Winner Amid Super Micro’s Accounting Troubles
# Inserted AMD Can’t Escape Nvidia’s Shadow. Wall Street Calls for Patience.
# Inserted Tempered AI Outlook, For Now -- Upgrading AMD To Buy For Intra-Quarter Trade
# Inserted AMD: Su Fumbles, Stock Tumbles, But There's A Silver Lining (Rating Downgrade)
# Inserted AMD Q3: Why The Stock Is Falling Despite Earnings Meeting Expectations
# Inserted AMD: Why I Am Aggressively Loading Up The Truck
# Inserted S&P 500: Mean Reversion Always Wins In The End
# Inserted AI, Data Centers And Energy Demand
# Inserted Baron Global Advantage Fund Q3 2024 Shareholder Letter
# Inserted Mega Tech Will Shape The Earnings Season And U.S. Markets When They Report This Week
# Inserted Pomerantz Law Firm Investigates Claims On Behalf of Investors of Tesla, Inc. - TSLA
# Inserted You Won't Believe What Elon Musk Just Said About Tesla
# Inserted Tesla Sells $499 Million of Debt Backed by Solar Equipment Loans
# Inserted Catherine Wood's Strategic Moves in Q3 2024: A Deep Dive into Zoom Video Communications' ...
# Inserted In 2016, Elon Musk Said It's 'Terrible To Make A Profit On Service.' Now, Repairs, Parts And Superchargers Are Beginning To Drive Its Profits
# Inserted How One Investor Made Retirement Happen With $61,600 In Annual Dividends
# Inserted Is Tesla, Inc. (TSLA) Set to Explode in 2025?
# Inserted Elon Musk Discovers Tesla Cybertruck's Biggest Enthusiast in Shaquille O'Neal
# Inserted BYD’s Sales Hit a Record. It’s Neck and Neck in EV Race With Tesla.
# Inserted Musk tests the role of money in U.S. politics with multimillion-dollar effort to back Trump
# Inserted Why Elon Musk and His Silicon Valley Allies Now Want Trump to Win
# Inserted Enphase Energy: Disappointing, But Not As Bad As It Seems
# Inserted Trump Vs. Harris: Top Stocks To Buy Or Avoid For The November 2024 Election
# Inserted Don’t Let Tesla’s Big Moves Fool You. Where the Chart Says the Stock Is Heading Next.
# Inserted Cathie Wood Shuffles Her Tech Deck: Continues Dumping Tesla And Palantir, Stocks Up On AMD And Meta
# Inserted Zacks Investment Ideas feature highlights: Alphabet, Tesla, Advanced Micro Devices, Root and Carvana
# Inserted Cathie Wood Bets Big On Mark Zuckerberg: Ark Pours $19M Into Meta Shares, Dumps Palantir And Tesla Stock
# Inserted Judge aims to rule on Elon Musk's $56 billion Tesla pay by year end
# Inserted Tracking Cathie Wood's ARK Invest 13F Portfolio - Q3 2024 Update
# Inserted Musk Ordered to Philadelphia Hearing Over $1 Million Voter Sweepstakes
# Inserted Tesla, Inc. (TSLA): Among The 10 Best S&P 500 Stocks to Buy According to Hedge Funds
# Inserted Tech Stocks: Staying Ahead Of The Curve
# Inserted Elon Musk Slams Zoox Co-Founder Over FSD Criticism: Your Company 'Would Be Dead Already' If Not For Amazon
# Inserted MicroStrategy’s $21 Billion Equity Plan Tops Tesla for Record
# Inserted Zacks Earnings Trends Highlights: Tesla, Alphabet and Microsoft
# Inserted Uber is transitioning into a 'software company': Investor
# Inserted Tesla Supplier STMicro Warns of Weaker Sales. ON Semi, Texas Instruments Stocks Fall.
# Inserted Elon Musk Reportedly Buying Up Huge Properties In Austin To House His 11 Kids And Their Mothers In Secret
# Inserted 1 Electric Vehicle ETF to Buy With 2025 Around the Corner
# Inserted Jim Cramer Rejects Fossil Fuel Naysayers: Bullish on Chevron (CVX)
# Inserted STMicro Sees Significant Sales Declines Persisting Into 2025
# Inserted Is Tesla, Inc. (TSLA) The Best EV Battery Stock To Buy in Late 2024?
# Inserted Nvidia: You Haven't Seen Anything Yet
# Inserted Meta, Microsoft AI Spending Is Causing Market Jitters. Why the Investing Won’t Stop and 5 Other Things to Know Today.
# Inserted Tesla’s robotaxi will make your commute worse. Elon Musk should focus on the less-hyped Robovan instead
# Inserted 2 Top Stocks That Can Supercharge Your Portfolio in 2025 and Beyond
# Inserted Will Lucid Be Worth More Than Tesla by 2040?
# Inserted Tesla Stock Closes Out Incredible Month. It’s Ending Where it Started.
# Inserted Frustrated By Tesla's Inability To Repair His Cybertruck, Man Used A $12 Part. Here's How He Solved The Issue
# Inserted Tech Flexes Earnings Power: A Closer Look
# Inserted Mag 7 earnings underline the group's huge market influence
# Inserted Tesla’s Sales Fall Behind BYD’s for the First Time. What It Means for Both Stocks.
# Inserted Is the EV Industry Facing Its Worst Growth Slowdown Amid Production Cuts?
# Inserted Cathie Wood's Sky-High Vision: Dumps Shares Of Cybercab Touting Tesla For This eVTOL Play
# Inserted Elon Musk's xAI Targets $40B Valuation as it Ramps Up Competition Against OpenAI
# Inserted 5 Things Investors Should Not See In A 'Healthy' Economy
# Inserted Elon Musk says there’s a 10% to 20% chance that AI ‘goes bad,’ even while he raises billions for his own startup xAI
# Inserted Why investors should buy the Mag 7 'right now'
# Inserted Will Tesla's Cybercab electrify the stock?
# Inserted Are Robust Financials Driving The Recent Rally In Tesla, Inc.'s (NASDAQ:TSLA) Stock?
# Inserted Has The Shyft Group (SHYF) Outpaced Other Auto-Tires-Trucks Stocks This Year?
# Inserted Elon Musk says Trump's economic plans will cause 'temporary hardship' and tank the stock market
# Inserted BYD Revenue Eclipses Tesla for First Time as EV Giants Go Head to Head
# Inserted Cocoa Prices Have More Than Doubled
# Inserted 1 Chart That Shows Why Tesla Is Still Overvalued
# Inserted Tesla Rocks, But They Are Behind Waymo With Robotaxis
# Inserted S&P 500: Mean Reversion Always Wins In The End
# Inserted California EV sales inch up but Tesla posts a decline
# Inserted Where Will Tesla Be in 10 Years?
# Inserted Only 10 Companies Have Reached a Trillion-Dollar Market Cap -- This Is the 1 That's a Screaming Buy Right Now
# Inserted A 'lot rides' on Big Tech earnings amid two busy weeks for markets
# Inserted Baron Global Advantage Fund Q3 2024 Shareholder Letter
# Inserted Mega Tech Will Shape The Earnings Season And U.S. Markets When They Report This Week
# Inserted Truth Social parent company Trump Media now worth more than Elon Musk’s X as Election Day nears
# Inserted Bots at the Wheel
# Inserted 'Room For One Prisoner' – California Police Chief Says Their $150,000 Tesla Model 3 Is 'Nearly Unusable'
# Inserted Alphabet stock soars as earnings crush estimates on strong cloud growth
# Inserted Dogecoin enjoys bump after Elon Musk boosts the crypto at Trump rally
# Inserted Elon Musk wins court victory in a dispute over a 2018 post during a labor dispute
# Inserted How Kamala Harris is trying to use Elon Musk against Donald Trump
# Inserted Tesla Stock Is Dropped. It Needs ‘Multiple New Models.’
# Inserted Should Netflix Replace Tesla in "Mag 7"? ETFs in Focus
# Inserted Tesla: I Like The Business, Not Sure About The Stock
# Inserted Elon Musk says there will be more humanoid robots than people in less than 20 years
# Inserted Elon Musk Admits 'Running Companies Hurts My Heart,' But Sees No Other Option For Building The Future. 'I Never Wanted To Be CEO'
# Inserted Elon Musk predicts more robots than humans by 2040
# Inserted Mega Tech Will Shape the Earnings Season and US Markets When They Report This Week
# Inserted Biden Calls Out Musk for Violating Visa Rules Amid Political Contributions
# Inserted Tesla robotaxi is a multi-trillion dollar opportunity - ARK
# Inserted Ford Trims Profit Forecast Over Costs, Hurricane Disruption
# Inserted Tesla: Finally More Than Just A Car Company
# Inserted What happens as EU concludes investigation of Chinese-made EVs?
# Inserted Musk Says He Sees Low Population Growth as a Key Risk
# Inserted Tesla: Early Signs Of Growth Inflection Raise Questions About Sustainability
# Inserted Tesla: Set To Have Its iPhone Moment
# Inserted Did Tesla Just Turn the Profit Corner?
# Inserted Tesla Stock: Margins Bounce Back For This AI Leader
# Inserted Tesla: Let's Clear Up Some Misconceptions
# Inserted Tesla’s Growth to Come From ‘Multiple New Models’. The Stock Is Down.
# Inserted Tesla: Rally Is Just Beginning (Rating Upgrade)
# Inserted Lucid to open orders for Gravity electric SUV next week
# Inserted The Zacks Analyst Blog Meta, Tesla, Thermo Fisher Scientific and Food Comes From
# Inserted What the Election Means for Tesla and Other Car Stocks
# Inserted Parnassus Growth Equity Fund Q3 2024 Commentary
# Inserted Harris Or Trump? How The Next President Could Change The Game For Stocks, Taxes, And Inflation
# Inserted Tesla: Dismantling the 2025 Bear Case (Debunking 5 Myths)
# Inserted 5 Reasons to be Bullish Stocks in Q4
# Inserted Alphabet Q3 earnings preview: AI updates in focus amid Big Tech's spending spree
# Inserted Tesla Traders Look for Stock to Break Out as Wall Street Gets More Bullish
# Inserted Top Analyst Reports for Meta Platforms, Tesla & Thermo Fisher Scientific
# Inserted Elon Musk Channels Warren Buffett As Tesla's Stock Booms After Strong Q3: 'Having A Publicly Traded Company Is Like...'
# Inserted Philadelphia DA sues Elon Musk for $1 million election sweepstakes—’indisputably’ unlawful
# Inserted Tech solutions to transport problems will not work
# Inserted Elon Musk Is Making Tesla Great Again (Technical Analysis)
# Inserted NLRB can’t order deletion of Musk’s anti-union tweets, 5th Circuit says
# Inserted Analysts reboot Tesla stock price target on innovation roadmap
# Inserted Tesla short sellers lose more than $4 billion on EV maker's post-earnings stock rally
# Inserted Tesla Insiders Plan to Sell $300 Million of Stock
# Inserted Volkswagen Stock Remains Undervalued Amid Cost-Cutting Moves
# Inserted ON Semiconductor: Pretty Impressive Performance For A Down Cycle
# Inserted Elon Musk claims he can cut the federal budget for Trump by 'at least' $2 trillion
# Inserted Elon Musk Warns of 'Financial Emergency' Amid U.S. Debt Crisis
# Inserted Tesla Outperforms In The Face Of Global Automotive Decline (Rating Upgrade)
# Inserted Wall Street Lunch: Putting Your Money Where Your Vote Is
# Inserted Tesla: A Rare Opportunity Presents Itself (Rating Upgrade)

# %%
print(dfg)
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7bc09a7e5a90>

# %%
connection.commit()

# %%
query = 'SELECT * FROM news_articles'

# %%
stock_req = get_nifty_50_tickers()

# %%
articles = cursor.execute(query).fetchall()

# %%
query = 'SELECT * FROM news_articles WHERE stock_symbol = ?'

# %%
for ticker in stock_req:
    articles = cursor.execute(query, (ticker,)).fetchall()
    print(f"\n--- {ticker} News ---")
    for article in articles:
        print(article)
